# %%
import warnings
warnings.filterwarnings('ignore')
import yfinance as yf
import pandas as pd
from pprint import pprint

# %%
data=yf.download('AAPL',start='1988-01-01',end='2024-12-10')
print(data.head())
data.to_csv("Stock_data_AAPL.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 1988-01-04  0.309216  0.399554  0.399554  0.377232  0.381696  330400000
# 1988-01-05  0.308353  0.398438  0.412946  0.395089  0.410714  309120000
# 1988-01-06  0.302306  0.390625  0.401786  0.390625  0.401786  268800000
# 1988-01-07  0.307488  0.397321  0.399554  0.379464  0.388393  212800000
# 1988-01-08  0.276394  0.357143  0.404018  0.352679  0.397321  486080000

# %%
stock_data = yf.Ticker("AAPL")

# %%
stock_data.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 164000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 62,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2023,
#    'totalPay': 16239562,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Luca  Maestri',
#    'age': 60,
#    'title': 'CFO & Senior VP',
#    'yearBorn': 1963,
#    'fiscalYear': 2023,
#    'totalPay': 4612242,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeffrey E. Williams',
#    'age': 59,
#    'title': 'Chief Operating Officer',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 4637585,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 59,
#    'title': 'Senior VP, General Counsel & Secretary',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 4618064,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 56,
#    'title': 'Chief People Officer & Senior VP of Retail',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'totalPay': 4613369,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Kondo',
#    'title': 'Senior Director of Corporate Accounting',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Adrian  Perica',
#    'age': 49,
#    'title': 'Head of Corporate Development',
#    'yearBorn': 1974,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Michael  Fenger',
#    'title': 'VP of Worldwide Sales',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 6,
#  'boardRisk': 1,
#  'compensationRisk': 2,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1733011200,
#  'compensationAsOfEpochDate': 1703980800,
#  'irWebsite': 'http://investor.apple.com/',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 259.02,
#  'open': 257.9,
#  'dayLow': 253.06,
#  'dayHigh': 258.7,
#  'regularMarketPreviousClose': 259.02,
#  'regularMarketOpen': 257.9,
#  'regularMarketDayLow': 253.06,
#  'regularMarketDayHigh': 258.7,
#  'dividendRate': 1.0,
#  'dividendYield': 0.0039,
#  'exDividendDate': 1731024000,
#  'payoutRatio': 0.1612,
#  'fiveYearAvgDividendYield': 0.62,
#  'beta': 1.24,
#  'trailingPE': 42.03783,
#  'forwardPE': 30.762213,
#  'volume': 42170447,
#  'regularMarketVolume': 42170447,
#  'averageVolume': 44123146,
#  'averageVolume10days': 53500590,
#  'averageDailyVolume10Day': 53500590,
#  'bid': 252.09,
#  'ask': 263.58,
#  'bidSize': 600,
#  'askSize': 1400,
#  'marketCap': 3863447076864,
#  'fiftyTwoWeekLow': 164.08,
#  'fiftyTwoWeekHigh': 260.1,
#  'priceToSalesTrailing12Months': 9.880054,
#  'fiftyDayAverage': 236.8936,
#  'twoHundredDayAverage': 212.62355,
#  'trailingAnnualDividendRate': 0.98,
#  'trailingAnnualDividendYield': 0.003783492,
#  'currency': 'USD',
#  'enterpriseValue': 3917341261824,
#  'profitMargins': 0.23971,
#  'floatShares': 15091184209,
#  'sharesOutstanding': 15115799552,
#  'sharesShort': 156458273,
#  'sharesShortPriorMonth': 141037864,
#  'sharesShortPreviousMonthDate': 1731628800,
#  'dateShortInterest': 1734048000,
#  'sharesPercentSharesOut': 0.0104,
#  'heldPercentInsiders': 0.02056,
#  'heldPercentInstitutions': 0.61934,
#  'shortRatio': 3.67,
#  'shortPercentOfFloat': 0.0104,
#  'impliedSharesOutstanding': 15115799552,
#  'bookValue': 3.767,
#  'priceToBook': 67.84975,
#  'lastFiscalYearEnd': 1727481600,
#  'nextFiscalYearEnd': 1759017600,
#  'mostRecentQuarter': 1727481600,
#  'earningsQuarterlyGrowth': -0.358,
#  'netIncomeToCommon': 93736001536,
#  'trailingEps': 6.08,
#  'forwardEps': 8.31,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 10.018,
#  'enterpriseToEbitda': 29.09,
#  '52WeekChange': 0.3768046,
#  'SandP52WeekChange': 0.25891924,
#  'lastDividendValue': 0.25,
#  'lastDividendDate': 1731024000,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'underlyingSymbol': 'AAPL',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'firstTradeDateEpochUtc': 345479400,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#  'messageBoardId': 'finmb_24937',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 255.59,
#  'targetHighPrice': 325.0,
#  'targetLowPrice': 184.0,
#  'targetMeanPrice': 246.85358,
#  'targetMedianPrice': 250.0,
#  'recommendationMean': 1.89362,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 42,
#  'totalCash': 65171001344,
#  'totalCashPerShare': 4.311,
#  'ebitda': 134660997120,
#  'totalDebt': 119058997248,
#  'quickRatio': 0.745,
#  'currentRatio': 0.867,
#  'totalRevenue': 391034994688,
#  'debtToEquity': 209.059,
#  'revenuePerShare': 25.485,
#  'returnOnAssets': 0.21464,
#  'returnOnEquity': 1.5741299,
#  'freeCashflow': 110846001152,
#  'operatingCashflow': 118254002176,
#  'earningsGrowth': -0.341,
#  'revenueGrowth': 0.061,
#  'grossMargins': 0.46206,
#  'ebitdaMargins': 0.34437,
#  'operatingMargins': 0.31171,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.337}

# %%
# Extract full stock data
stock_data_info = stock_data.info

# Extract only the important information
stock_data_info = {
    'Company Details': {
        'name': stock_data_info['longName'],
        'symbol': stock_data_info['symbol'],
        'industry': stock_data_info['industry'],
        'sector': stock_data_info['sector'],
        'address': stock_data_info['address1'],
        'city': stock_data_info['city'],
        'state': stock_data_info['state'],
        'zip': stock_data_info['zip'],
        'country': stock_data_info['country'],
        'phone': stock_data_info['phone'],
        'website': stock_data_info['website'],
        'longBusinessSummary': stock_data_info['longBusinessSummary'],
        'fullTimeEmployees': stock_data_info['fullTimeEmployees'],
        'companyOfficers': stock_data_info['companyOfficers']
    },
    'Stock Details': {
        'currentPrice': stock_data_info['currentPrice'],
        'previousClose': stock_data_info['previousClose'],
        'open': stock_data_info['open'],
        'dayLow': stock_data_info['dayLow'],
        'dayHigh': stock_data_info['dayHigh'],
        'regularMarketPreviousClose': stock_data_info['regularMarketPreviousClose'],
        'regularMarketOpen': stock_data_info['regularMarketOpen'],
        'regularMarketDayLow': stock_data_info['regularMarketDayLow'],
        'regularMarketDayHigh': stock_data_info['regularMarketDayHigh'],
        'fiftyTwoWeekLow': stock_data_info['fiftyTwoWeekLow'],
        'fiftyTwoWeekHigh': stock_data_info['fiftyTwoWeekHigh'],
        'fiftyDayAverage': stock_data_info['fiftyDayAverage'],
        'twoHundredDayAverage': stock_data_info['twoHundredDayAverage'],
        'marketCap': stock_data_info['marketCap']
    },
    'Volume and Shares': {
        'volume': stock_data_info['volume'],
        'regularMarketVolume': stock_data_info['regularMarketVolume'],
        'averageVolume': stock_data_info['averageVolume'],
        'averageVolume10days': stock_data_info['averageVolume10days'],
        'sharesOutstanding': stock_data_info['sharesOutstanding'],
        'floatShares': stock_data_info['floatShares'],
        'impliedSharesOutstanding': stock_data_info['impliedSharesOutstanding']
    },
    'Dividends and Yield': {
        'dividendRate': stock_data_info['dividendRate'],
        'dividendYield': stock_data_info['dividendYield'],
        'exDividendDate': stock_data_info['exDividendDate'],
        'payoutRatio': stock_data_info['payoutRatio'],
        'trailingAnnualDividendRate': stock_data_info['trailingAnnualDividendRate'],
        'trailingAnnualDividendYield': stock_data_info['trailingAnnualDividendYield']
    },
    'Financial Performance': {
        'totalRevenue': stock_data_info['totalRevenue'],
        'revenuePerShare': stock_data_info['revenuePerShare'],
        'earningsGrowth': stock_data_info['earningsGrowth'],
        'revenueGrowth': stock_data_info['revenueGrowth'],
        'returnOnAssets': stock_data_info['returnOnAssets'],
        'returnOnEquity': stock_data_info['returnOnEquity'],
        'grossMargins': stock_data_info['grossMargins'],
        'operatingMargins': stock_data_info['operatingMargins']
    },
    'Financial Ratios': {
        'priceToBook': stock_data_info['priceToBook'],
        'debtToEquity': stock_data_info['debtToEquity'],
        'enterpriseToRevenue': stock_data_info['enterpriseToRevenue'],
        'enterpriseToEbitda': stock_data_info['enterpriseToEbitda'],
        'beta': stock_data_info['beta'],
        'trailingPE': stock_data_info['trailingPE'],
        'forwardPE': stock_data_info['forwardPE']
    },
    'Cash Flow': {
        'totalCash': stock_data_info['totalCash'],
        'totalCashPerShare': stock_data_info['totalCashPerShare'],
        'freeCashflow': stock_data_info['freeCashflow'],
        'operatingCashflow': stock_data_info['operatingCashflow']
    },
    'Analyst Targets': {
        'targetHighPrice': stock_data_info['targetHighPrice'],
        'targetLowPrice': stock_data_info['targetLowPrice'],
        'targetMeanPrice': stock_data_info['targetMeanPrice'],
        'targetMedianPrice': stock_data_info['targetMedianPrice'],
        'recommendationKey': stock_data_info['recommendationKey'],
        'recommendationMean': stock_data_info['recommendationMean']
    },
    'Governance and Risks': {
        'auditRisk': stock_data_info['auditRisk'],
        'boardRisk': stock_data_info['boardRisk'],
        'compensationRisk': stock_data_info['compensationRisk'],
        'shareHolderRightsRisk': stock_data_info['shareHolderRightsRisk'],
        'overallRisk': stock_data_info['overallRisk']
    }
}

# %%
pprint(stock_data_info)
# Out:
# {'Analyst Targets': {'recommendationKey': 'buy',
#                      'recommendationMean': 1.89362,
#                      'targetHighPrice': 325.0,
#                      'targetLowPrice': 184.0,
#                      'targetMeanPrice': 246.85358,
#                      'targetMedianPrice': 250.0},
#  'Cash Flow': {'freeCashflow': 110846001152,
#                'operatingCashflow': 118254002176,
#                'totalCash': 65171001344,
#                'totalCashPerShare': 4.311},
#  'Company Details': {'address': 'One Apple Park Way',
#                      'city': 'Cupertino',
#                      'companyOfficers': [{'age': 62,
#                                           'exercisedValue': 0,
#                                           'fiscalYear': 2023,
#                                           'maxAge': 1,
#                                           'name': 'Mr. Timothy D. Cook',
#                                           'title': 'CEO & Director',
#                                           'totalPay': 16239562,
#                                           'unexercisedValue': 0,
#                                           'yearBorn': 1961},
#                                          {'age': 60,
#                                           'exercisedValue': 0,
#                                           'fiscalYear': 2023,
#                                           'maxAge': 1,
#                                           'name': 'Mr. Luca  Maestri',
#                                           'title': 'CFO & Senior VP',
#                                           'totalPay': 4612242,
#                                           'unexercisedValue': 0,
#                                           'yearBorn': 1963},
#                                          {'age': 59,
#                                           'exercisedValue': 0,
#                                           'fiscalYear': 2023,
#                                           'maxAge': 1,
#                                           'name': 'Mr. Jeffrey E. Williams',
#                                           'title': 'Chief Operating Officer',
#                                           'totalPay': 4637585,
#                                           'unexercisedValue': 0,
#                                           'yearBorn': 1964},
#                                          {'age': 59,
#                                           'exercisedValue': 0,
#                                           'fiscalYear': 2023,
#                                           'maxAge': 1,
#                                           'name': 'Ms. Katherine L. Adams',
#                                           'title': 'Senior VP, General Counsel '
#                                                    '& Secretary',
#                                           'totalPay': 4618064,
#                                           'unexercisedValue': 0,
#                                           'yearBorn': 1964},
#                                          {'age': 56,
#                                           'exercisedValue': 0,
#                                           'fiscalYear': 2023,
#                                           'maxAge': 1,
#                                           'name': "Ms. Deirdre  O'Brien",
#                                           'title': 'Chief People Officer & '
#                                                    'Senior VP of Retail',
#                                           'totalPay': 4613369,
#                                           'unexercisedValue': 0,
#                                           'yearBorn': 1967},
#                                          {'exercisedValue': 0,
#                                           'fiscalYear': 2023,
#                                           'maxAge': 1,
#                                           'name': 'Mr. Chris  Kondo',
#                                           'title': 'Senior Director of '
#                                                    'Corporate Accounting',
#                                           'unexercisedValue': 0},
#                                          {'exercisedValue': 0,
#                                           'fiscalYear': 2023,
#                                           'maxAge': 1,
#                                           'name': 'Suhasini  Chandramouli',
#                                           'title': 'Director of Investor '
#                                                    'Relations',
#                                           'unexercisedValue': 0},
#                                          {'exercisedValue': 0,
#                                           'fiscalYear': 2023,
#                                           'maxAge': 1,
#                                           'name': 'Mr. Greg  Joswiak',
#                                           'title': 'Senior Vice President of '
#                                                    'Worldwide Marketing',
#                                           'unexercisedValue': 0},
#                                          {'age': 49,
#                                           'exercisedValue': 0,
#                                           'fiscalYear': 2023,
#                                           'maxAge': 1,
#                                           'name': 'Mr. Adrian  Perica',
#                                           'title': 'Head of Corporate '
#                                                    'Development',
#                                           'unexercisedValue': 0,
#                                           'yearBorn': 1974},
#                                          {'exercisedValue': 0,
#                                           'fiscalYear': 2023,
#                                           'maxAge': 1,
#                                           'name': 'Mr. Michael  Fenger',
#                                           'title': 'VP of Worldwide Sales',
#                                           'unexercisedValue': 0}],
#                      'country': 'United States',
#                      'fullTimeEmployees': 164000,
#                      'industry': 'Consumer Electronics',
#                      'longBusinessSummary': 'Apple Inc. designs, manufactures, '
#                                             'and markets smartphones, personal '
#                                             'computers, tablets, wearables, '
#                                             'and accessories worldwide. The '
#                                             'company offers iPhone, a line of '
#                                             'smartphones; Mac, a line of '
#                                             'personal computers; iPad, a line '
#                                             'of multi-purpose tablets; and '
#                                             'wearables, home, and accessories '
#                                             'comprising AirPods, Apple TV, '
#                                             'Apple Watch, Beats products, and '
#                                             'HomePod. It also provides '
#                                             'AppleCare support and cloud '
#                                             'services; and operates various '
#                                             'platforms, including the App '
#                                             'Store that allow customers to '
#                                             'discover and download '
#                                             'applications and digital content, '
#                                             'such as books, music, video, '
#                                             'games, and podcasts, as well as '
#                                             'advertising services include '
#                                             'third-party licensing '
#                                             'arrangements and its own '
#                                             'advertising platforms. In '
#                                             'addition, the company offers '
#                                             'various subscription-based '
#                                             'services, such as Apple Arcade, a '
#                                             'game subscription service; Apple '
#                                             'Fitness+, a personalized fitness '
#                                             'service; Apple Music, which '
#                                             'offers users a curated listening '
#                                             'experience with on-demand radio '
#                                             'stations; Apple News+, a '
#                                             'subscription news and magazine '
#                                             'service; Apple TV+, which offers '
#                                             'exclusive original content; Apple '
#                                             'Card, a co-branded credit card; '
#                                             'and Apple Pay, a cashless payment '
#                                             'service, as well as licenses its '
#                                             'intellectual property. The '
#                                             'company serves consumers, and '
#                                             'small and mid-sized businesses; '
#                                             'and the education, enterprise, '
#                                             'and government markets. It '
#                                             'distributes third-party '
#                                             'applications for its products '
#                                             'through the App Store. The '
#                                             'company also sells its products '
#                                             'through its retail and online '
#                                             'stores, and direct sales force; '
#                                             'and third-party cellular network '
#                                             'carriers, wholesalers, retailers, '
#                                             'and resellers. Apple Inc. was '
#                                             'founded in 1976 and is '
#                                             'headquartered in Cupertino, '
#                                             'California.',
#                      'name': 'Apple Inc.',
#                      'phone': '(408) 996-1010',
#                      'sector': 'Technology',
#                      'state': 'CA',
#                      'symbol': 'AAPL',
#                      'website': 'https://www.apple.com',
#                      'zip': '95014'},
#  'Dividends and Yield': {'dividendRate': 1.0,
#                          'dividendYield': 0.0039,
#                          'exDividendDate': 1731024000,
#                          'payoutRatio': 0.1612,
#                          'trailingAnnualDividendRate': 0.98,
#                          'trailingAnnualDividendYield': 0.003783492},
#  'Financial Performance': {'earningsGrowth': -0.341,
#                            'grossMargins': 0.46206,
#                            'operatingMargins': 0.31171,
#                            'returnOnAssets': 0.21464,
#                            'returnOnEquity': 1.5741299,
#                            'revenueGrowth': 0.061,
#                            'revenuePerShare': 25.485,
#                            'totalRevenue': 391034994688},
#  'Financial Ratios': {'beta': 1.24,
#                       'debtToEquity': 209.059,
#                       'enterpriseToEbitda': 29.09,
#                       'enterpriseToRevenue': 10.018,
#                       'forwardPE': 30.762213,
#                       'priceToBook': 67.84975,
#                       'trailingPE': 42.03783},
#  'Governance and Risks': {'auditRisk': 6,
#                           'boardRisk': 1,
#                           'compensationRisk': 2,
#                           'overallRisk': 1,
#                           'shareHolderRightsRisk': 1},
#  'Stock Details': {'currentPrice': 255.59,
#                    'dayHigh': 258.7,
#                    'dayLow': 253.06,
#                    'fiftyDayAverage': 236.8936,
#                    'fiftyTwoWeekHigh': 260.1,
#                    'fiftyTwoWeekLow': 164.08,
#                    'marketCap': 3863447076864,
#                    'open': 257.9,
#                    'previousClose': 259.02,
#                    'regularMarketDayHigh': 258.7,
#                    'regularMarketDayLow': 253.06,
#                    'regularMarketOpen': 257.9,
#                    'regularMarketPreviousClose': 259.02,
#                    'twoHundredDayAverage': 212.62355},
#  'Volume and Shares': {'averageVolume': 44123146,
#                        'averageVolume10days': 53500590,
#                        'floatShares': 15091184209,
#                        'impliedSharesOutstanding': 15115799552,
#                        'regularMarketVolume': 42170447,
#                        'sharesOutstanding': 15115799552,
#                        'volume': 42170447}}

# %%
periods = {
    '1d': ['1m', '2m', '5m', '15m', '30m', '60m', '90m'],
    '5d': ['1m', '2m', '5m', '15m', '30m', '60m', '90m'],
    '1mo': ['30m', '60m', '90m', '1d'],
    '3mo': ['1d', '5d', '1wk', '1mo'],
    '6mo': ['1d', '5d', '1wk', '1mo'],
    '1y': ['1d', '5d', '1wk', '1mo'],
    '2y': ['1d', '5d', '1wk', '1mo'],
    '5y': ['1d', '5d', '1wk', '1mo'],
    '10y': ['1d', '5d', '1wk', '1mo'],
    'max': ['1d', '5d', '1wk', '1mo'],
}

# %%
stock_data_hist = stock_data.history(period="10y", interval="1d")
stock_data_hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-12-29 00:00:00-05:00   25.340385   25.558625   25.320342   25.367109
# 2014-12-30 00:00:00-05:00   25.306984   25.369338   24.966262   25.057566
# 2014-12-31 00:00:00-05:00   25.124376   25.193411   24.543144   24.581001
# 2015-01-02 00:00:00-05:00   24.805927   24.817063   23.906242   24.347178
# 2015-01-05 00:00:00-05:00   24.115573   24.195743   23.474213   23.661276
# ...                               ...         ...         ...         ...
# 2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002  254.490005
# 2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997  255.270004
# 2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993  258.200012
# 2024-12-26 00:00:00-05:00  258.190002  260.100006  257.630005  259.019989
# 2024-12-27 00:00:00-05:00  257.829987  258.700012  253.059998  255.589996
#
#                               Volume  Dividends  Stock Splits
# Date
# 2014-12-29 00:00:00-05:00  110395600        0.0           0.0
# 2014-12-30 00:00:00-05:00  119526000        0.0           0.0
# 2014-12-31 00:00:00-05:00  165613600        0.0           0.0
# 2015-01-02 00:00:00-05:00  212818400        0.0           0.0
# 2015-01-05 00:00:00-05:00  257142000        0.0           0.0
# ...                              ...        ...           ...
# 2024-12-20 00:00:00-05:00  147495300        0.0           0.0
# 2024-12-23 00:00:00-05:00   40858800        0.0           0.0
# 2024-12-24 00:00:00-05:00   23234700        0.0           0.0
# 2024-12-26 00:00:00-05:00   27237100        0.0           0.0
# 2024-12-27 00:00:00-05:00   42317100        0.0           0.0
#
# [2517 rows x 7 columns]

# %%
stock_data_hist.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
# Drop the unnecessary "index" column if it exists
if 'index' in stock_data_hist.columns:
    stock_data_hist = stock_data_hist.drop(columns=['index'])

# Reset the index to integers and keep "Date" as a column
stock_data_hist = stock_data_hist.reset_index()

# Verify the corrected DataFrame
print(stock_data_hist.head())
# Out:
#                        Date       Open       High        Low      Close  \
# 0 2014-12-29 00:00:00-05:00  25.340385  25.558625  25.320342  25.367109
# 1 2014-12-30 00:00:00-05:00  25.306984  25.369338  24.966262  25.057566
# 2 2014-12-31 00:00:00-05:00  25.124376  25.193411  24.543144  24.581001
# 3 2015-01-02 00:00:00-05:00  24.805927  24.817063  23.906242  24.347178
# 4 2015-01-05 00:00:00-05:00  24.115573  24.195743  23.474213  23.661276
#
#       Volume  Dividends  Stock Splits
# 0  110395600        0.0           0.0
# 1  119526000        0.0           0.0
# 2  165613600        0.0           0.0
# 3  212818400        0.0           0.0
# 4  257142000        0.0           0.0

# %%
print(stock_data_hist.head())
# Out:
#                        Date       Open       High        Low      Close  \
# 0 2014-12-29 00:00:00-05:00  25.340385  25.558625  25.320342  25.367109
# 1 2014-12-30 00:00:00-05:00  25.306984  25.369338  24.966262  25.057566
# 2 2014-12-31 00:00:00-05:00  25.124376  25.193411  24.543144  24.581001
# 3 2015-01-02 00:00:00-05:00  24.805927  24.817063  23.906242  24.347178
# 4 2015-01-05 00:00:00-05:00  24.115573  24.195743  23.474213  23.661276
#
#       Volume  Dividends  Stock Splits
# 0  110395600        0.0           0.0
# 1  119526000        0.0           0.0
# 2  165613600        0.0           0.0
# 3  212818400        0.0           0.0
# 4  257142000        0.0           0.0

# %%
stock_data_hist.tail()
# Out:
#                           Date        Open        High         Low  \
# 2512 2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002
# 2513 2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997
# 2514 2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993
# 2515 2024-12-26 00:00:00-05:00  258.190002  260.100006  257.630005
# 2516 2024-12-27 00:00:00-05:00  257.829987  258.700012  253.059998
#
#            Close     Volume  Dividends  Stock Splits
# 2512  254.490005  147495300        0.0           0.0
# 2513  255.270004   40858800        0.0           0.0
# 2514  258.200012   23234700        0.0           0.0
# 2515  259.019989   27237100        0.0           0.0
# 2516  255.589996   42317100        0.0           0.0

# %%
df=stock_data_hist[['Date','Close']]

# %%
import matplotlib.pyplot as plt
plt.plot(df['Date'], df['Close'])

# %%
df1=df.reset_index()['Close']
df2=df.reset_index()['Date']

# %%
print(df2)
# Out:
# 0      2014-12-29 00:00:00-05:00
# 1      2014-12-30 00:00:00-05:00
# 2      2014-12-31 00:00:00-05:00
# 3      2015-01-02 00:00:00-05:00
# 4      2015-01-05 00:00:00-05:00
#                   ...
# 2512   2024-12-20 00:00:00-05:00
# 2513   2024-12-23 00:00:00-05:00
# 2514   2024-12-24 00:00:00-05:00
# 2515   2024-12-26 00:00:00-05:00
# 2516   2024-12-27 00:00:00-05:00
# Name: Date, Length: 2517, dtype: datetime64[ns, America/New_York]

# %%
print(df1)
# Out:
# 0        25.367109
# 1        25.057566
# 2        24.581001
# 3        24.347178
# 4        23.661276
#            ...
# 2512    254.490005
# 2513    255.270004
# 2514    258.200012
# 2515    259.019989
# 2516    255.589996
# Name: Close, Length: 2517, dtype: float64

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
print(df1)
# Out:
# [[0.01959465]
#  [0.0182958 ]
#  [0.01629614]
#  ...
#  [0.99655938]
#  [1.        ]
#  [0.98560778]]

# %%
#df2=scaler.inverse_transform(df1)
#print(df2)

# %%
#print (df1)

# %%
train_size = int(len(df1) * 0.8)  # 70% for training
val_size = int(len(df1) * 0.1)    # 10% for validation
test_size = len(df1) - train_size - val_size  # Remaining 20% for testing
train_data = df1[0:train_size, :]
validation_data = df1[train_size:train_size + val_size, :]
test_data = df1[train_size + val_size:, :1]

# %%
df2=np.array(df2).reshape(-1,1)

# %%
train_size_date = int(len(df2) * 0.8)  # 70% for training
val_size_date = int(len(df2) * 0.1)    # 10% for validation
test_size_date = len(df2) - train_size - val_size  # Remaining 20% for testing
train_data_date = df2[0:train_size, :]
validation_data_date = df2[train_size:train_size + val_size, :]
test_data_date = df2[train_size + val_size:, :1]

# %%
print(train_size),print(val_size)
# Out:
# 2013
# 251
# (None, None)

# %%
import numpy as np
def create_dataset(dataset,time_step=1):
    datax,datay=[],[]
    for i in range(len(dataset)-time_step-1):
        a=dataset[i:(i+ time_step),0]
        datax.append(a)
        datay.append(dataset[i+time_step,0])
    return np.array(datax),np.array(datay)

# %%
time_step=30
x_train,y_train=create_dataset(train_data,time_step)
x_test,y_test=create_dataset(test_data,time_step)
x_val,y_val=create_dataset(validation_data,time_step)

# %%
time_step=30
x_train_date,y_train_date=create_dataset(train_data_date,time_step)
x_test_date,y_test_date=create_dataset(test_data_date,time_step)
x_val_date,y_val_date=create_dataset(validation_data_date,time_step)

# %%
print(x_train.shape), print(y_train.shape),print(x_val.shape),print(x_test.shape)
# Out:
# (1982, 30)
# (1982,)
# (220, 30)
# (222, 30)
# (None, None, None, None)

# %%
x_train =x_train.reshape(x_train.shape[0],x_train.shape[1] , 1)
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1] , 1)
x_val =x_val.reshape(x_val.shape[0],x_val.shape[1] , 1)

# %%
print (x_train)
# Out:
# [[[0.01959465]
#   [0.0182958 ]
#   [0.01629614]
#   ...
#   [0.02472404]
#   [0.02546514]
#   [0.0276228 ]]
#
#  [[0.0182958 ]
#   [0.01629614]
#   [0.01531502]
#   ...
#   [0.02546514]
#   [0.0276228 ]
#   [0.03030582]]
#
#  [[0.01629614]
#   [0.01531502]
#   [0.01243698]
#   ...
#   [0.0276228 ]
#   [0.03030582]
#   [0.03178804]]
#
#  ...
#
#  [[0.48999561]
#   [0.49240393]
#   [0.47317861]
#   ...
#   [0.47994683]
#   [0.47168367]
#   [0.46279779]]
#
#  [[0.49240393]
#   [0.47317861]
#   [0.52300645]
#   ...
#   [0.47168367]
#   [0.46279779]
#   [0.46250711]]
#
#  [[0.47317861]
#   [0.52300645]
#   [0.5347576 ]
#   ...
#   [0.46279779]
#   [0.46250711]
#   [0.47558681]]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Define the model
model = Sequential([
    layers.Input((30, 1)),
    layers.LSTM(64),
    layers.Dense(32, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

# Compile the model
model.compile(
    loss='mse',
    optimizer=Adam(learning_rate=0.001),
    metrics=['mean_absolute_error']
)

# Define the callbacks
checkpoint = ModelCheckpoint(
    filepath='best_lstm_model.keras',  # File to save the best weights
    monitor='val_loss',            # Metric to monitor
    save_best_only=True,           # Save only the best model
    save_weights_only=False,       # Save the full model
    mode='min',                    # Minimize the monitored metric
    verbose=1                      # Verbosity
)

early_stop = EarlyStopping(
    monitor='val_loss',            # Metric to monitor
    patience=10,                   # Stop training after 10 epochs without improvement
    restore_best_weights=True,     # Restore the best weights at the end of training
    verbose=1                      # Verbosity
)

# Train the model with callbacks
model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=50,
    callbacks=[checkpoint, early_stop]
)

# Save the final model (optional, as the best model is already saved)
model.save('final_lstm_model.h5')
# Out:
# Epoch 1/50
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0321 - mean_absolute_error: 0.1077
# Epoch 1: val_loss improved from inf to 0.00040, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0301 - mean_absolute_error: 0.1025 - val_loss: 3.9970e-04 - val_mean_absolute_error: 0.0157
# Epoch 2/50
# 55/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5226e-04 - mean_absolute_error: 0.0102
# Epoch 2: val_loss did not improve from 0.00040
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5102e-04 - mean_absolute_error: 0.0102 - val_loss: 5.4764e-04 - val_mean_absolute_error: 0.0168
# Epoch 3/50
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2932e-04 - mean_absolute_error: 0.0096
# Epoch 3: val_loss did not improve from 0.00040
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2903e-04 - mean_absolute_error: 0.0096 - val_loss: 5.1541e-04 - val_mean_absolute_error: 0.0198
# Epoch 4/50
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0532e-04 - mean_absolute_error: 0.0092
# Epoch 4: val_loss did not improve from 0.00040
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0671e-04 - mean_absolute_error: 0.0092 - val_loss: 4.1751e-04 - val_mean_absolute_error: 0.0177
# Epoch 5/50
# 53/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5238e-04 - mean_absolute_error: 0.0102
# Epoch 5: val_loss did not improve from 0.00040
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4786e-04 - mean_absolute_error: 0.0101 - val_loss: 8.4771e-04 - val_mean_absolute_error: 0.0254
# Epoch 6/50
# 58/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9416e-04 - mean_absolute_error: 0.0087
# Epoch 6: val_loss did not improve from 0.00040
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9474e-04 - mean_absolute_error: 0.0087 - val_loss: 4.6435e-04 - val_mean_absolute_error: 0.0187
# Epoch 7/50
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8283e-04 - mean_absolute_error: 0.0089
# Epoch 7: val_loss improved from 0.00040 to 0.00038, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8463e-04 - mean_absolute_error: 0.0089 - val_loss: 3.8348e-04 - val_mean_absolute_error: 0.0168
# Epoch 8/50
# 55/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4450e-04 - mean_absolute_error: 0.0076
# Epoch 8: val_loss did not improve from 0.00038
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4679e-04 - mean_absolute_error: 0.0077 - val_loss: 9.5564e-04 - val_mean_absolute_error: 0.0273
# Epoch 9/50
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7918e-04 - mean_absolute_error: 0.0085
# Epoch 9: val_loss improved from 0.00038 to 0.00031, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8008e-04 - mean_absolute_error: 0.0086 - val_loss: 3.0932e-04 - val_mean_absolute_error: 0.0134
# Epoch 10/50
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7372e-04 - mean_absolute_error: 0.0084
# Epoch 10: val_loss did not improve from 0.00031
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7260e-04 - mean_absolute_error: 0.0084 - val_loss: 3.7005e-04 - val_mean_absolute_error: 0.0164
# Epoch 11/50
# 59/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3118e-04 - mean_absolute_error: 0.0072
# Epoch 11: val_loss improved from 0.00031 to 0.00023, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3137e-04 - mean_absolute_error: 0.0072 - val_loss: 2.3331e-04 - val_mean_absolute_error: 0.0122
# Epoch 12/50
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4271e-04 - mean_absolute_error: 0.0076
# Epoch 12: val_loss did not improve from 0.00023
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4226e-04 - mean_absolute_error: 0.0076 - val_loss: 2.3993e-04 - val_mean_absolute_error: 0.0118
# Epoch 13/50
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2568e-04 - mean_absolute_error: 0.0073
# Epoch 13: val_loss did not improve from 0.00023
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2582e-04 - mean_absolute_error: 0.0073 - val_loss: 2.3875e-04 - val_mean_absolute_error: 0.0127
# Epoch 14/50
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2546e-04 - mean_absolute_error: 0.0072
# Epoch 14: val_loss did not improve from 0.00023
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2564e-04 - mean_absolute_error: 0.0072 - val_loss: 6.4221e-04 - val_mean_absolute_error: 0.0225
# Epoch 15/50
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3226e-04 - mean_absolute_error: 0.0074
# Epoch 15: val_loss did not improve from 0.00023
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3158e-04 - mean_absolute_error: 0.0073 - val_loss: 3.3716e-04 - val_mean_absolute_error: 0.0154
# Epoch 16/50
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0315e-04 - mean_absolute_error: 0.0068
# Epoch 16: val_loss improved from 0.00023 to 0.00017, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0432e-04 - mean_absolute_error: 0.0068 - val_loss: 1.7313e-04 - val_mean_absolute_error: 0.0103
# Epoch 17/50
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0328e-04 - mean_absolute_error: 0.0063
# Epoch 17: val_loss did not improve from 0.00017
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0516e-04 - mean_absolute_error: 0.0064 - val_loss: 1.8810e-04 - val_mean_absolute_error: 0.0111
# Epoch 18/50
# 59/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1323e-04 - mean_absolute_error: 0.0069
# Epoch 18: val_loss did not improve from 0.00017
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1367e-04 - mean_absolute_error: 0.0070 - val_loss: 2.5521e-04 - val_mean_absolute_error: 0.0132
# Epoch 19/50
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0689e-04 - mean_absolute_error: 0.0064
# Epoch 19: val_loss improved from 0.00017 to 0.00017, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0634e-04 - mean_absolute_error: 0.0064 - val_loss: 1.7294e-04 - val_mean_absolute_error: 0.0106
# Epoch 20/50
# 53/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3974e-04 - mean_absolute_error: 0.0077
# Epoch 20: val_loss did not improve from 0.00017
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3606e-04 - mean_absolute_error: 0.0076 - val_loss: 2.3476e-04 - val_mean_absolute_error: 0.0126
# Epoch 21/50
# 59/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1881e-04 - mean_absolute_error: 0.0068
# Epoch 21: val_loss did not improve from 0.00017
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1982e-04 - mean_absolute_error: 0.0069 - val_loss: 3.0411e-04 - val_mean_absolute_error: 0.0146
# Epoch 22/50
# 55/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1530e-04 - mean_absolute_error: 0.0071
# Epoch 22: val_loss did not improve from 0.00017
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1454e-04 - mean_absolute_error: 0.0071 - val_loss: 2.3698e-04 - val_mean_absolute_error: 0.0127
# Epoch 23/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9231e-05 - mean_absolute_error: 0.0063
# Epoch 23: val_loss did not improve from 0.00017
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9181e-05 - mean_absolute_error: 0.0063 - val_loss: 4.1059e-04 - val_mean_absolute_error: 0.0176
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1483e-04 - mean_absolute_error: 0.0072
# Epoch 24: val_loss improved from 0.00017 to 0.00015, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1466e-04 - mean_absolute_error: 0.0072 - val_loss: 1.5480e-04 - val_mean_absolute_error: 0.0097
# Epoch 25/50
# 58/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0500e-04 - mean_absolute_error: 0.0067
# Epoch 25: val_loss did not improve from 0.00015
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0427e-04 - mean_absolute_error: 0.0067 - val_loss: 1.8209e-04 - val_mean_absolute_error: 0.0109
# Epoch 26/50
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0585e-05 - mean_absolute_error: 0.0057
# Epoch 26: val_loss did not improve from 0.00015
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2211e-05 - mean_absolute_error: 0.0058 - val_loss: 3.5367e-04 - val_mean_absolute_error: 0.0162
# Epoch 27/50
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1539e-04 - mean_absolute_error: 0.0067
# Epoch 27: val_loss did not improve from 0.00015
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1328e-04 - mean_absolute_error: 0.0067 - val_loss: 2.2440e-04 - val_mean_absolute_error: 0.0124
# Epoch 28/50
# 58/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1469e-05 - mean_absolute_error: 0.0059
# Epoch 28: val_loss improved from 0.00015 to 0.00013, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1242e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3037e-04 - val_mean_absolute_error: 0.0090
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0448e-05 - mean_absolute_error: 0.0056
# Epoch 29: val_loss did not improve from 0.00013
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0572e-05 - mean_absolute_error: 0.0056 - val_loss: 2.3798e-04 - val_mean_absolute_error: 0.0128
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1898e-05 - mean_absolute_error: 0.0064
# Epoch 30: val_loss did not improve from 0.00013
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2212e-05 - mean_absolute_error: 0.0065 - val_loss: 2.1433e-04 - val_mean_absolute_error: 0.0121
# Epoch 31/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0710e-04 - mean_absolute_error: 0.0068
# Epoch 31: val_loss did not improve from 0.00013
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0673e-04 - mean_absolute_error: 0.0068 - val_loss: 2.4934e-04 - val_mean_absolute_error: 0.0132
# Epoch 32/50
# 59/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0033e-04 - mean_absolute_error: 0.0064
# Epoch 32: val_loss did not improve from 0.00013
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0048e-04 - mean_absolute_error: 0.0064 - val_loss: 2.8464e-04 - val_mean_absolute_error: 0.0143
# Epoch 33/50
# 53/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3521e-05 - mean_absolute_error: 0.0062
# Epoch 33: val_loss did not improve from 0.00013
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5812e-05 - mean_absolute_error: 0.0063 - val_loss: 2.9134e-04 - val_mean_absolute_error: 0.0138
# Epoch 34/50
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0843e-04 - mean_absolute_error: 0.0070
# Epoch 34: val_loss did not improve from 0.00013
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0728e-04 - mean_absolute_error: 0.0070 - val_loss: 1.3214e-04 - val_mean_absolute_error: 0.0088
# Epoch 35/50
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3609e-05 - mean_absolute_error: 0.0057
# Epoch 35: val_loss improved from 0.00013 to 0.00012, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3750e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2466e-04 - val_mean_absolute_error: 0.0089
# Epoch 36/50
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1827e-05 - mean_absolute_error: 0.0061
# Epoch 36: val_loss did not improve from 0.00012
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1778e-05 - mean_absolute_error: 0.0061 - val_loss: 5.8893e-04 - val_mean_absolute_error: 0.0223
# Epoch 37/50
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4563e-05 - mean_absolute_error: 0.0063
# Epoch 37: val_loss improved from 0.00012 to 0.00012, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3318e-05 - mean_absolute_error: 0.0063 - val_loss: 1.1928e-04 - val_mean_absolute_error: 0.0087
# Epoch 38/50
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8311e-05 - mean_absolute_error: 0.0055
# Epoch 38: val_loss did not improve from 0.00012
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8496e-05 - mean_absolute_error: 0.0055 - val_loss: 2.1561e-04 - val_mean_absolute_error: 0.0122
# Epoch 39/50
# 53/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.7792e-05 - mean_absolute_error: 0.0062
# Epoch 39: val_loss did not improve from 0.00012
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7167e-05 - mean_absolute_error: 0.0061 - val_loss: 2.9126e-04 - val_mean_absolute_error: 0.0147
# Epoch 40/50
# 59/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6216e-05 - mean_absolute_error: 0.0054
# Epoch 40: val_loss did not improve from 0.00012
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6372e-05 - mean_absolute_error: 0.0054 - val_loss: 2.2675e-04 - val_mean_absolute_error: 0.0126
# Epoch 41/50
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3340e-05 - mean_absolute_error: 0.0061
# Epoch 41: val_loss improved from 0.00012 to 0.00012, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3812e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1771e-04 - val_mean_absolute_error: 0.0086
# Epoch 42/50
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8800e-05 - mean_absolute_error: 0.0066
# Epoch 42: val_loss did not improve from 0.00012
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7902e-05 - mean_absolute_error: 0.0065 - val_loss: 1.5417e-04 - val_mean_absolute_error: 0.0096
# Epoch 43/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0622e-05 - mean_absolute_error: 0.0060
# Epoch 43: val_loss did not improve from 0.00012
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0812e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2189e-04 - val_mean_absolute_error: 0.0088
# Epoch 44/50
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2023e-05 - mean_absolute_error: 0.0063
# Epoch 44: val_loss did not improve from 0.00012
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1909e-05 - mean_absolute_error: 0.0063 - val_loss: 1.9070e-04 - val_mean_absolute_error: 0.0109
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0548e-05 - mean_absolute_error: 0.0055
# Epoch 45: val_loss improved from 0.00012 to 0.00011, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.0482e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1453e-04 - val_mean_absolute_error: 0.0084
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6098e-05 - mean_absolute_error: 0.0057
# Epoch 46: val_loss did not improve from 0.00011
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.6085e-05 - mean_absolute_error: 0.0057 - val_loss: 4.2042e-04 - val_mean_absolute_error: 0.0185
# Epoch 47/50
# 55/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0749e-05 - mean_absolute_error: 0.0056
# Epoch 47: val_loss improved from 0.00011 to 0.00010, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1288e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0306e-04 - val_mean_absolute_error: 0.0080
# Epoch 48/50
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7960e-05 - mean_absolute_error: 0.0051
# Epoch 48: val_loss improved from 0.00010 to 0.00010, saving model to best_lstm_model.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8876e-05 - mean_absolute_error: 0.0052 - val_loss: 9.8754e-05 - val_mean_absolute_error: 0.0078
# Epoch 49/50
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0231e-04 - mean_absolute_error: 0.0067
# Epoch 49: val_loss did not improve from 0.00010
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0018e-04 - mean_absolute_error: 0.0066 - val_loss: 1.3293e-04 - val_mean_absolute_error: 0.0092
# Epoch 50/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0138e-05 - mean_absolute_error: 0.0052
# Epoch 50: val_loss did not improve from 0.00010
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0111e-05 - mean_absolute_error: 0.0052 - val_loss: 1.0787e-04 - val_mean_absolute_error: 0.0081
# Restoring model weights from the end of the best epoch: 48.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
train_pred=model.predict(x_train)
test_pred=model.predict(x_test)
val_predict=model.predict(x_val)
print(test_pred)
print("hiiiii")
print(y_test)

print("hoooooo")
print(test_pred.dtype)
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [[0.70206404]
#  [0.7030184 ]
#  [0.6990872 ]
#  [0.6916508 ]
#  [0.6856418 ]
#  [0.6822259 ]
#  [0.67727214]
#  [0.67340976]
#  [0.67382604]
#  [0.67960924]
#  [0.67849165]
#  [0.67446667]
#  [0.6758434 ]
#  [0.6737903 ]
#  [0.67111266]
#  [0.66715944]
#  [0.6542197 ]
#  [0.63566655]
#  [0.6242782 ]
#  [0.6194377 ]
#  [0.62256014]
#  [0.6302884 ]
#  [0.63614196]
#  [0.6341167 ]
#  [0.6370767 ]
#  [0.63752097]
#  [0.6401107 ]
#  [0.6469535 ]
#  [0.65659314]
#  [0.64363486]
#  [0.6380596 ]
#  [0.6317428 ]
#  [0.62605405]
#  [0.6322595 ]
#  [0.63189393]
#  [0.628352  ]
#  [0.6236501 ]
#  [0.623264  ]
#  [0.6214348 ]
#  [0.62252635]
#  [0.62064594]
#  [0.62263924]
#  [0.6193188 ]
#  [0.63489515]
#  [0.64706045]
#  [0.6436408 ]
#  [0.6327384 ]
#  [0.6230135 ]
#  [0.6157333 ]
#  [0.60765547]
#  [0.60616094]
#  [0.6088358 ]
#  [0.6160253 ]
#  [0.6222606 ]
#  [0.62398595]
#  [0.6344637 ]
#  [0.6320747 ]
#  [0.62751776]
#  [0.63357884]
#  [0.65929013]
#  [0.66899854]
#  [0.6747929 ]
#  [0.6777374 ]
#  [0.6821409 ]
#  [0.6815242 ]
#  [0.68729424]
#  [0.6926253 ]
#  [0.6998896 ]
#  [0.70394516]
#  [0.7058842 ]
#  [0.70891875]
#  [0.71298414]
#  [0.712226  ]
#  [0.7032742 ]
#  [0.70477724]
#  [0.7061141 ]
#  [0.70779365]
#  [0.7107917 ]
#  [0.7143817 ]
#  [0.71979624]
#  [0.7231775 ]
#  [0.72768027]
#  [0.7271207 ]
#  [0.73116815]
#  [0.7257623 ]
#  [0.7495412 ]
#  [0.7679991 ]
#  [0.78036493]
#  [0.78718626]
#  [0.7957892 ]
#  [0.79925424]
#  [0.7907811 ]
#  [0.7805696 ]
#  [0.7768112 ]
#  [0.77769786]
#  [0.7873644 ]
#  [0.79471296]
#  [0.79172677]
#  [0.801579  ]
#  [0.8129166 ]
#  [0.82123524]
#  [0.8331002 ]
#  [0.8413755 ]
#  [0.84797853]
#  [0.85689086]
#  [0.85459244]
#  [0.8569606 ]
#  [0.8653227 ]
#  [0.870917  ]
#  [0.8632818 ]
#  [0.8491705 ]
#  [0.84189576]
#  [0.8383977 ]
#  [0.83970994]
#  [0.82803744]
#  [0.8190704 ]
#  [0.8166557 ]
#  [0.8172197 ]
#  [0.8188837 ]
#  [0.8263561 ]
#  [0.8229484 ]
#  [0.8235846 ]
#  [0.80091363]
#  [0.78287584]
#  [0.78133184]
#  [0.79083663]
#  [0.80200636]
#  [0.8105895 ]
#  [0.82184404]
#  [0.8277179 ]
#  [0.83545244]
#  [0.84143174]
#  [0.8438246 ]
#  [0.8457357 ]
#  [0.84633976]
#  [0.8431563 ]
#  [0.84569234]
#  [0.84796876]
#  [0.8508945 ]
#  [0.84962016]
#  [0.8550783 ]
#  [0.85668576]
#  [0.84507066]
#  [0.8346408 ]
#  [0.83270115]
#  [0.8293816 ]
#  [0.82838756]
#  [0.82669485]
#  [0.8310954 ]
#  [0.83384734]
#  [0.8346197 ]
#  [0.82242924]
#  [0.81650484]
#  [0.82163393]
#  [0.8409564 ]
#  [0.84948355]
#  [0.8503092 ]
#  [0.85150486]
#  [0.84991455]
#  [0.8507989 ]
#  [0.85180944]
#  [0.86193234]
#  [0.8551211 ]
#  [0.85166   ]
#  [0.84772974]
#  [0.8481884 ]
#  [0.8386287 ]
#  [0.8418779 ]
#  [0.8517106 ]
#  [0.8561719 ]
#  [0.8551622 ]
#  [0.8613615 ]
#  [0.8690347 ]
#  [0.8692666 ]
#  [0.86956733]
#  [0.8746372 ]
#  [0.88006663]
#  [0.88178426]
#  [0.87291485]
#  [0.86708564]
#  [0.86608636]
#  [0.8701338 ]
#  [0.87324536]
#  [0.8677775 ]
#  [0.8563046 ]
#  [0.8441157 ]
#  [0.83582175]
#  [0.8365033 ]
#  [0.8359119 ]
#  [0.84545875]
#  [0.8501889 ]
#  [0.8468084 ]
#  [0.84440726]
#  [0.84469324]
#  [0.8510323 ]
#  [0.847991  ]
#  [0.85204124]
#  [0.85468704]
#  [0.857331  ]
#  [0.8575444 ]
#  [0.860105  ]
#  [0.86684144]
#  [0.8743456 ]
#  [0.8779575 ]
#  [0.88380814]
#  [0.890778  ]
#  [0.89979535]
#  [0.9050233 ]
#  [0.9074492 ]
#  [0.90805   ]
#  [0.91529644]
#  [0.92117697]
#  [0.9219171 ]
#  [0.92475504]
#  [0.92660457]
#  [0.93288934]
#  [0.9407873 ]
#  [0.9350669 ]
#  [0.93475324]
#  [0.9433278 ]
#  [0.94965523]
#  [0.9580892 ]]
# hiiiii
# [0.7027105  0.695603   0.68678134 0.68306036 0.68184797 0.67536754
#  0.67223194 0.67540947 0.68398015 0.67624559 0.67055965 0.67670548
#  0.67164662 0.66884543 0.6642884  0.64522358 0.62440292 0.62022198
#  0.61972033 0.62695313 0.63539857 0.63740533 0.62862561 0.63644379
#  0.63485506 0.63945396 0.64932084 0.66014932 0.62962896 0.63343356
#  0.62745496 0.62268882 0.6377398  0.63008885 0.62402664 0.61905133
#  0.62243784 0.61896784 0.62214518 0.61742085 0.62252146 0.61461966
#  0.64497273 0.65128586 0.63514766 0.62130907 0.61553945 0.61152581
#  0.60299688 0.60650875 0.61094042 0.61980395 0.62344132 0.6209746
#  0.63853417 0.62528091 0.6209746  0.63656916 0.67984108 0.67285914
#  0.67574382 0.67716538 0.68481639 0.67949944 0.693022   0.69783648
#  0.70742369 0.70792604 0.70805165 0.71294988 0.71843426 0.71236379
#  0.69553392 0.70851213 0.70855406 0.70980999 0.71399651 0.7180156
#  0.72546755 0.72680729 0.73317081 0.72735151 0.73744113 0.72165783
#  0.78039491 0.80517928 0.8100775  0.80275104 0.82025074 0.81028674
#  0.79098688 0.7818184  0.78453956 0.78843309 0.8059328  0.80949141
#  0.79492216 0.82058566 0.83532228 0.84068104 0.86073448 0.86693063
#  0.87053099 0.88853304 0.865884   0.87831793 0.89447796 0.89623636
#  0.87136832 0.85169154 0.85223583 0.8507706  0.85516641 0.82807949
#  0.82368374 0.82565138 0.82682363 0.82916806 0.84289991 0.82732597
#  0.83360575 0.78927042 0.78072983 0.79157304 0.80618397 0.8184506
#  0.82490529 0.84058103 0.84246716 0.85504131 0.86061584 0.85994523
#  0.86254384 0.86208279 0.85424495 0.86392699 0.86535208 0.86891472
#  0.86246003 0.87629158 0.87298042 0.8468681  0.83882071 0.84523346
#  0.83869496 0.83907214 0.83571904 0.84640705 0.8468681  0.84573645
#  0.81983374 0.82180362 0.83815004 0.8724355  0.86962727 0.86237622
#  0.86614843 0.86195705 0.86677716 0.86790882 0.88974595 0.86128651
#  0.86367556 0.85902307 0.86375937 0.84234142 0.85944224 0.87524373
#  0.87314804 0.86690291 0.88262059 0.8933086  0.8846324  0.88618323
#  0.89812865 0.90433191 0.90173329 0.88035721 0.87956092 0.88308164
#  0.89142246 0.89255412 0.87759092 0.86002904 0.8474549  0.84368263
#  0.84971821 0.84665855 0.86660948 0.86547661 0.85402151 0.85402151
#  0.85775593 0.87076353 0.85725244 0.86992435 0.87101528 0.8740364
#  0.87202234 0.87768689 0.89027486 0.89946409 0.89891859 0.90898901
#  0.91847193 0.93131165 0.93282221 0.93294808 0.9321089  0.94851524
#  0.95279517 0.9474243  0.95359242 0.95430573 0.96651601 0.97675424
#  0.95397004 0.96127102 0.98099223 0.9842651  0.99655938 1.        ]
# hoooooo
# float32

# %%
y_train.dtype
# Out:
# dtype('float64')

# %%
train_pred.dtype
# Out:
# dtype('float32')

# %%
plt.plot(y_train)
plt.plot(train_pred)
plt.show()

# %%
plt.plot(y_val,color="red")
plt.plot(val_predict)
plt.show()

# %%
plt.plot(y_test,color="red")
plt.plot(test_pred,color="green")

plt.show()

# %%
print(len(y_train))
print(len(train_pred))
# Out:
# 1982
# 1982

# %%
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))
test_pred_scaled= scaler.inverse_transform(test_pred.reshape(-1, 1))
plt.plot(y_test_scaled,color="red")
plt.plot(test_pred_scaled,color="green")
plt.show()

# %%
scaler.scale_
# Out:
# array([0.00419599])

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Assuming 'df1' contains the original data before scaling

  # Fit the scaler on the original data

# Forecast for the next 90 days
forecast_days = 30
predictions = []

# Start with the last sequence from x_test (shape: (1, 100, 1))
current_input = x_test[-1:]  # Take the last sequence from the validation data (shape: (1, 100, 1))

for _ in range(forecast_days):
    # Predict the next time step
    next_pred = model.predict(current_input)
    predictions.append(next_pred[0, 0])
    
    # Update current_input with the predicted value, and shift the sequence
    current_input = np.roll(current_input, -1, axis=1)
    current_input[0, -1, 0] = next_pred  # Set the last time step to the predicted value

# Convert predictions to a numpy array
predictions = np.array(predictions)
  
# Transform predictions back to the original scale
predictions_original_scale = scaler.inverse_transform(predictions.reshape(-1, 1))

# Print forecast for the next 90 days on the original scale
print("Forecast for the next 90 days on test data (original scale):", predictions_original_scale.flatten())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forecast for the next 90 days on test data (original scale): [249.03168 246.11592 242.9553  239.78398 236.81252 234.03516 231.38799
#  228.96861 226.76016 224.7414  222.89034 221.18588 219.609   218.14311
#  216.77425 215.4908  214.28328 213.14388 212.06635 211.04553 210.07715
#  209.15593 208.2775  207.4401  206.64125 205.87875 205.15059 204.45508
#  203.79054 203.15549]
